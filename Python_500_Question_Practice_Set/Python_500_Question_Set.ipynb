# %% [markdown]
# # Python Complete 500-Question Challenge Workbook
# ---
# This workbook contains all 500 tasks segmented through 20 structured curriculum levels.
# Write your implementation solutions directly inside the code snippets placed below each specification block.

# %% [markdown]
# ## Level 1: Topic 1: Python Basics — Variables, Data Types & Input/Output
# ---

# %% [markdown]
# ### **Question 1** *(Topic 1.1)*
# > Write a Python program to declare variables of types int, float, str, bool and print each with its type.

# %%
# TODO: Implement Solution for Question 1

# %% [markdown]
# ### **Question 2** *(Topic 1.2)*
# > How do you accept a number from the user and print whether it is positive, negative, or zero?

# %%
# TODO: Implement Solution for Question 2

# %% [markdown]
# ### **Question 3** *(Topic 1.3)*
# > Write a Python program to swap two variables without using a third variable.

# %%
# TODO: Implement Solution for Question 3

# %% [markdown]
# ### **Question 4** *(Topic 1.4)*
# > How do you convert a string input to an integer and perform arithmetic on it?

# %%
# TODO: Implement Solution for Question 4

# %% [markdown]
# ### **Question 5** *(Topic 1.5)*
# > Write a Python program to calculate the area of a rectangle using user-provided length and width.

# %%
# TODO: Implement Solution for Question 5

# %% [markdown]
# ### **Question 6** *(Topic 1.6)*
# > How do you print a multiline string using triple quotes?

# %%
# TODO: Implement Solution for Question 6

# %% [markdown]
# ### **Question 7** *(Topic 1.7)*
# > Write a Python program to find the size (in bytes) of different data types using sys.getsizeof().

# %%
# TODO: Implement Solution for Question 7

# %% [markdown]
# ### **Question 8** *(Topic 1.8)*
# > How do you check the data type of a variable using type() and isinstance()?

# %%
# TODO: Implement Solution for Question 8

# %% [markdown]
# ### **Question 9** *(Topic 1.9)*
# > Write a Python program to demonstrate implicit and explicit type conversion with examples.

# %%
# TODO: Implement Solution for Question 9

# %% [markdown]
# ### **Question 10** *(Topic 1.10)*
# > How do you print formatted output using f-strings, .format(), and % formatting?

# %%
# TODO: Implement Solution for Question 10

# %% [markdown]
# ### **Question 11** *(Topic 1.11)*
# > Write a Python program that takes two numbers as input and prints their sum, difference, product, and quotient.

# %%
# TODO: Implement Solution for Question 11

# %% [markdown]
# ### **Question 12** *(Topic 1.12)*
# > How do you read multiple values from a single input line separated by spaces?

# %%
# TODO: Implement Solution for Question 12

# %% [markdown]
# ### **Question 13** *(Topic 1.13)*
# > Write a Python program to find the simple interest given principal, rate, and time.

# %%
# TODO: Implement Solution for Question 13

# %% [markdown]
# ### **Question 14** *(Topic 1.14)*
# > How do you use the print() function with sep and end parameters?

# %%
# TODO: Implement Solution for Question 14

# %% [markdown]
# ### **Question 15** *(Topic 1.15)*
# > Write a Python program to convert temperature from Celsius to Fahrenheit and vice versa.

# %%
# TODO: Implement Solution for Question 15

# %% [markdown]
# ### **Question 16** *(Topic 1.16)*
# > How do you determine if a variable is None and handle it safely?

# %%
# TODO: Implement Solution for Question 16

# %% [markdown]
# ### **Question 17** *(Topic 1.17)*
# > Write a Python program to display the binary, octal, and hexadecimal representations of a number.

# %%
# TODO: Implement Solution for Question 17

# %% [markdown]
# ### **Question 18** *(Topic 1.18)*
# > How do you use the id() function to check if two variables point to the same object?

# %%
# TODO: Implement Solution for Question 18

# %% [markdown]
# ### **Question 19** *(Topic 1.19)*
# > Write a Python program to compute the floor division and modulus of two numbers.

# %%
# TODO: Implement Solution for Question 19

# %% [markdown]
# ### **Question 20** *(Topic 1.20)*
# > How do you assign multiple variables in a single line using tuple unpacking?

# %%
# TODO: Implement Solution for Question 20

# %% [markdown]
# ### **Question 21** *(Topic 1.21)*
# > Write a Python program to check if two strings are equal using == and the is operator, explaining the difference.

# %%
# TODO: Implement Solution for Question 21

# %% [markdown]
# ### **Question 22** *(Topic 1.22)*
# > How do you use the input() function to build a simple greeting program?

# %%
# TODO: Implement Solution for Question 22

# %% [markdown]
# ### **Question 23** *(Topic 1.23)*
# > Write a Python program to calculate the perimeter and area of a circle given its radius.

# %%
# TODO: Implement Solution for Question 23

# %% [markdown]
# ### **Question 24** *(Topic 1.24)*
# > How do you print a pattern of stars using nested print statements (without loops)?

# %%
# TODO: Implement Solution for Question 24

# %% [markdown]
# ### **Question 25** *(Topic 1.25)*
# > Write a Python program to find the maximum of three numbers using only comparison operators.

# %%
# TODO: Implement Solution for Question 25

# %% [markdown]
# ## Level 2: Topic 2: Operators & Expressions
# ---

# %% [markdown]
# ### **Question 26** *(Topic 2.1)*
# > Write a Python program to demonstrate all arithmetic operators (+, -, *, /, //, %, **).

# %%
# TODO: Implement Solution for Question 26

# %% [markdown]
# ### **Question 27** *(Topic 2.2)*
# > How do you use comparison operators (==, !=, <, >, <=, >=) to compare two values?

# %%
# TODO: Implement Solution for Question 27

# %% [markdown]
# ### **Question 28** *(Topic 2.3)*
# > Write a Python program to demonstrate all logical operators (and, or, not) with truth table examples.

# %%
# TODO: Implement Solution for Question 28

# %% [markdown]
# ### **Question 29** *(Topic 2.4)*
# > How do you use bitwise operators (&, |, ^, ~, <<, >>) with integer values?

# %%
# TODO: Implement Solution for Question 29

# %% [markdown]
# ### **Question 30** *(Topic 2.5)*
# > Write a Python program to demonstrate assignment operators (=, +=, -=, *=, /=, //=, **=, %=).

# %%
# TODO: Implement Solution for Question 30

# %% [markdown]
# ### **Question 31** *(Topic 2.6)*
# > How do you use the identity operators is and is not to compare objects?

# %%
# TODO: Implement Solution for Question 31

# %% [markdown]
# ### **Question 32** *(Topic 2.7)*
# > Write a Python program to demonstrate membership operators in and not in on a list and string.

# %%
# TODO: Implement Solution for Question 32

# %% [markdown]
# ### **Question 33** *(Topic 2.8)*
# > How do you evaluate operator precedence in a complex expression like 3 + 2 * 5 ** 2 - 10 / 2?

# %%
# TODO: Implement Solution for Question 33

# %% [markdown]
# ### **Question 34** *(Topic 2.9)*
# > Write a Python program to determine if a number is divisible by both 3 and 5 using logical operators.

# %%
# TODO: Implement Solution for Question 34

# %% [markdown]
# ### **Question 35** *(Topic 2.10)*
# > How do you use the ternary (conditional) operator to assign a value based on a condition?

# %%
# TODO: Implement Solution for Question 35

# %% [markdown]
# ### **Question 36** *(Topic 2.11)*
# > Write a Python program to check if a year is a leap year using logical and arithmetic operators.

# %%
# TODO: Implement Solution for Question 36

# %% [markdown]
# ### **Question 37** *(Topic 2.12)*
# > How do you perform bitwise left and right shifts to multiply and divide by powers of 2?

# %%
# TODO: Implement Solution for Question 37

# %% [markdown]
# ### **Question 38** *(Topic 2.13)*
# > Write a Python program to swap two bits at given positions in an integer.

# %%
# TODO: Implement Solution for Question 38

# %% [markdown]
# ### **Question 39** *(Topic 2.14)*
# > How do you compute the XOR of two numbers and explain its use in toggling bits?

# %%
# TODO: Implement Solution for Question 39

# %% [markdown]
# ### **Question 40** *(Topic 2.15)*
# > Write a Python program to find the absolute difference of two numbers without using abs().

# %%
# TODO: Implement Solution for Question 40

# %% [markdown]
# ### **Question 41** *(Topic 2.16)*
# > How do you chain comparison operators (e.g., 1 < x < 10) in Python?

# %%
# TODO: Implement Solution for Question 41

# %% [markdown]
# ### **Question 42** *(Topic 2.17)*
# > Write a Python program to determine the sign of a number using the walrus operator (:=).

# %%
# TODO: Implement Solution for Question 42

# %% [markdown]
# ### **Question 43** *(Topic 2.18)*
# > How do you use augmented assignment operators inside a loop to accumulate a sum?

# %%
# TODO: Implement Solution for Question 43

# %% [markdown]
# ### **Question 44** *(Topic 2.19)*
# > Write a Python program to compute the power of a number using the ** operator and math.pow().

# %%
# TODO: Implement Solution for Question 44

# %% [markdown]
# ### **Question 45** *(Topic 2.20)*
# > How do you evaluate short-circuit behavior of and and or operators with examples?

# %%
# TODO: Implement Solution for Question 45

# %% [markdown]
# ### **Question 46** *(Topic 2.21)*
# > Write a Python program to check if a number is even or odd using the bitwise & operator.

# %%
# TODO: Implement Solution for Question 46

# %% [markdown]
# ### **Question 47** *(Topic 2.22)*
# > How do you use the // operator to compute integer division and compare it with int(a/b)?

# %%
# TODO: Implement Solution for Question 47

# %% [markdown]
# ### **Question 48** *(Topic 2.23)*
# > Write a Python program to convert a decimal number to binary using arithmetic operators only.

# %%
# TODO: Implement Solution for Question 48

# %% [markdown]
# ### **Question 49** *(Topic 2.24)*
# > How do you combine membership and logical operators to validate if a character is a vowel?

# %%
# TODO: Implement Solution for Question 49

# %% [markdown]
# ### **Question 50** *(Topic 2.25)*
# > Write a Python program to compute the result of a Boolean expression and print its truth value.

# %%
# TODO: Implement Solution for Question 50

# %% [markdown]
# ## Level 3: Topic 3: Control Flow — if, elif, else
# ---

# %% [markdown]
# ### **Question 51** *(Topic 3.1)*
# > Write a Python program to check if a number is positive, negative, or zero.

# %%
# TODO: Implement Solution for Question 51

# %% [markdown]
# ### **Question 52** *(Topic 3.2)*
# > How do you use if-elif-else to classify a student's grade (A, B, C, D, F) from a numeric score?

# %%
# TODO: Implement Solution for Question 52

# %% [markdown]
# ### **Question 53** *(Topic 3.3)*
# > Write a Python program to find the largest among three numbers using if-elif-else.

# %%
# TODO: Implement Solution for Question 53

# %% [markdown]
# ### **Question 54** *(Topic 3.4)*
# > How do you check if a character is a vowel or consonant?

# %%
# TODO: Implement Solution for Question 54

# %% [markdown]
# ### **Question 55** *(Topic 3.5)*
# > Write a Python program to determine if a triangle is equilateral, isosceles, or scalene.

# %%
# TODO: Implement Solution for Question 55

# %% [markdown]
# ### **Question 56** *(Topic 3.6)*
# > How do you use nested if statements to check if a person is eligible to vote and drive?

# %%
# TODO: Implement Solution for Question 56

# %% [markdown]
# ### **Question 57** *(Topic 3.7)*
# > Write a Python program to find the roots of a quadratic equation using the discriminant.

# %%
# TODO: Implement Solution for Question 57

# %% [markdown]
# ### **Question 58** *(Topic 3.8)*
# > How do you check if a number is divisible by 2, 3, or both using if-elif-else?

# %%
# TODO: Implement Solution for Question 58

# %% [markdown]
# ### **Question 59** *(Topic 3.9)*
# > Write a Python program that acts as a simple calculator using if-elif-else for +, -, *, /.

# %%
# TODO: Implement Solution for Question 59

# %% [markdown]
# ### **Question 60** *(Topic 3.10)*
# > How do you validate user input to ensure it is within a specific range?

# %%
# TODO: Implement Solution for Question 60

# %% [markdown]
# ### **Question 61** *(Topic 3.11)*
# > Write a Python program to classify a BMI value as Underweight, Normal, Overweight, or Obese.

# %%
# TODO: Implement Solution for Question 61

# %% [markdown]
# ### **Question 62** *(Topic 3.12)*
# > How do you check if a number is a perfect number using if and a loop?

# %%
# TODO: Implement Solution for Question 62

# %% [markdown]
# ### **Question 63** *(Topic 3.13)*
# > Write a Python program to print the day name for a number 1–7 using if-elif-else (no dict/list).

# %%
# TODO: Implement Solution for Question 63

# %% [markdown]
# ### **Question 64** *(Topic 3.14)*
# > How do you implement a simple login system that checks username and password?

# %%
# TODO: Implement Solution for Question 64

# %% [markdown]
# ### **Question 65** *(Topic 3.15)*
# > Write a Python program to determine electricity billing based on unit consumption slabs.

# %%
# TODO: Implement Solution for Question 65

# %% [markdown]
# ### **Question 66** *(Topic 3.16)*
# > How do you use a ternary expression inside a print statement?

# %%
# TODO: Implement Solution for Question 66

# %% [markdown]
# ### **Question 67** *(Topic 3.17)*
# > Write a Python program to check if a given year is a leap year.

# %%
# TODO: Implement Solution for Question 67

# %% [markdown]
# ### **Question 68** *(Topic 3.18)*
# > How do you handle division by zero using a conditional check?

# %%
# TODO: Implement Solution for Question 68

# %% [markdown]
# ### **Question 69** *(Topic 3.19)*
# > Write a Python program to classify a character as uppercase, lowercase, digit, or special character.

# %%
# TODO: Implement Solution for Question 69

# %% [markdown]
# ### **Question 70** *(Topic 3.20)*
# > How do you use chained elif to implement a number-to-grade conversion table?

# %%
# TODO: Implement Solution for Question 70

# %% [markdown]
# ### **Question 71** *(Topic 3.21)*
# > Write a Python program to simulate a traffic light (Red/Yellow/Green) using if-elif-else.

# %%
# TODO: Implement Solution for Question 71

# %% [markdown]
# ### **Question 72** *(Topic 3.22)*
# > How do you determine the type of a triangle (acute, right, obtuse) given its three sides?

# %%
# TODO: Implement Solution for Question 72

# %% [markdown]
# ### **Question 73** *(Topic 3.23)*
# > Write a Python program to check if a number is between 1 and 100 using nested conditions.

# %%
# TODO: Implement Solution for Question 73

# %% [markdown]
# ### **Question 74** *(Topic 3.24)*
# > How do you use if __name__ == '__main__': and explain its purpose?

# %%
# TODO: Implement Solution for Question 74

# %% [markdown]
# ### **Question 75** *(Topic 3.25)*
# > Write a Python program to find the maximum of a list of numbers without using max().

# %%
# TODO: Implement Solution for Question 75

# %% [markdown]
# ## Level 4: Topic 4: Loops — for, while, break, continue, pass
# ---

# %% [markdown]
# ### **Question 76** *(Topic 4.1)*
# > Write a Python program to print numbers from 1 to 50 using a for loop.

# %%
# TODO: Implement Solution for Question 76

# %% [markdown]
# ### **Question 77** *(Topic 4.2)*
# > How do you use a while loop to print the multiplication table of a given number?

# %%
# TODO: Implement Solution for Question 77

# %% [markdown]
# ### **Question 78** *(Topic 4.3)*
# > Write a Python program to find the sum of all digits in a number using a while loop.

# %%
# TODO: Implement Solution for Question 78

# %% [markdown]
# ### **Question 79** *(Topic 4.4)*
# > How do you use break to exit a loop when a target value is found in a list?

# %%
# TODO: Implement Solution for Question 79

# %% [markdown]
# ### **Question 80** *(Topic 4.5)*
# > Write a Python program to skip even numbers and print only odd numbers using continue.

# %%
# TODO: Implement Solution for Question 80

# %% [markdown]
# ### **Question 81** *(Topic 4.6)*
# > How do you use pass inside a loop as a placeholder for future code?

# %%
# TODO: Implement Solution for Question 81

# %% [markdown]
# ### **Question 82** *(Topic 4.7)*
# > Write a Python program to print the Fibonacci sequence up to n terms.

# %%
# TODO: Implement Solution for Question 82

# %% [markdown]
# ### **Question 83** *(Topic 4.8)*
# > How do you use the range() function with start, stop, and step parameters?

# %%
# TODO: Implement Solution for Question 83

# %% [markdown]
# ### **Question 84** *(Topic 4.9)*
# > Write a Python program to find all prime numbers between 1 and 100 using nested loops.

# %%
# TODO: Implement Solution for Question 84

# %% [markdown]
# ### **Question 85** *(Topic 4.10)*
# > How do you reverse a number using a while loop?

# %%
# TODO: Implement Solution for Question 85

# %% [markdown]
# ### **Question 86** *(Topic 4.11)*
# > Write a Python program to check if a number is an Armstrong number.

# %%
# TODO: Implement Solution for Question 86

# %% [markdown]
# ### **Question 87** *(Topic 4.12)*
# > How do you print a right-angled triangle pattern of stars using nested for loops?

# %%
# TODO: Implement Solution for Question 87

# %% [markdown]
# ### **Question 88** *(Topic 4.13)*
# > Write a Python program to find the factorial of a number using a for loop.

# %%
# TODO: Implement Solution for Question 88

# %% [markdown]
# ### **Question 89** *(Topic 4.14)*
# > How do you use enumerate() in a for loop to get both index and value?

# %%
# TODO: Implement Solution for Question 89

# %% [markdown]
# ### **Question 90** *(Topic 4.15)*
# > Write a Python program to find the GCD of two numbers using a while loop.

# %%
# TODO: Implement Solution for Question 90

# %% [markdown]
# ### **Question 91** *(Topic 4.16)*
# > How do you use the else clause with a for/while loop and when does it execute?

# %%
# TODO: Implement Solution for Question 91

# %% [markdown]
# ### **Question 92** *(Topic 4.17)*
# > Write a Python program to count vowels and consonants in a string using a loop.

# %%
# TODO: Implement Solution for Question 92

# %% [markdown]
# ### **Question 93** *(Topic 4.18)*
# > How do you flatten a nested list using nested for loops?

# %%
# TODO: Implement Solution for Question 93

# %% [markdown]
# ### **Question 94** *(Topic 4.19)*
# > Write a Python program to generate a multiplication table (1–10) using nested loops.

# %%
# TODO: Implement Solution for Question 94

# %% [markdown]
# ### **Question 95** *(Topic 4.20)*
# > How do you use zip() to iterate over two lists simultaneously in a for loop?

# %%
# TODO: Implement Solution for Question 95

# %% [markdown]
# ### **Question 96** *(Topic 4.21)*
# > Write a Python program to find the LCM of two numbers using a while loop.

# %%
# TODO: Implement Solution for Question 96

# %% [markdown]
# ### **Question 97** *(Topic 4.22)*
# > How do you implement an infinite loop with a controlled exit using break?

# %%
# TODO: Implement Solution for Question 97

# %% [markdown]
# ### **Question 98** *(Topic 4.23)*
# > Write a Python program to print Pascal's triangle up to n rows.

# %%
# TODO: Implement Solution for Question 98

# %% [markdown]
# ### **Question 99** *(Topic 4.24)*
# > How do you iterate over a dictionary using a for loop with .items(), .keys(), .values()?

# %%
# TODO: Implement Solution for Question 99

# %% [markdown]
# ### **Question 100** *(Topic 4.25)*
# > Write a Python program to count the frequency of each element in a list using a loop.

# %%
# TODO: Implement Solution for Question 100

# %% [markdown]
# ## Level 5: Topic 5: Functions & Scope
# ---

# %% [markdown]
# ### **Question 101** *(Topic 5.1)*
# > Write a Python function to check if a number is prime.

# %%
# TODO: Implement Solution for Question 101

# %% [markdown]
# ### **Question 102** *(Topic 5.2)*
# > How do you define a function with default parameter values?

# %%
# TODO: Implement Solution for Question 102

# %% [markdown]
# ### **Question 103** *(Topic 5.3)*
# > Write a Python function that accepts *args and returns their sum.

# %%
# TODO: Implement Solution for Question 103

# %% [markdown]
# ### **Question 104** *(Topic 5.4)*
# > How do you use **kwargs to build a function that creates a user profile dictionary?

# %%
# TODO: Implement Solution for Question 104

# %% [markdown]
# ### **Question 105** *(Topic 5.5)*
# > Write a Python program to demonstrate the difference between local and global scope.

# %%
# TODO: Implement Solution for Question 105

# %% [markdown]
# ### **Question 106** *(Topic 5.6)*
# > How do you use the global keyword to modify a global variable inside a function?

# %%
# TODO: Implement Solution for Question 106

# %% [markdown]
# ### **Question 107** *(Topic 5.7)*
# > Write a Python function that returns multiple values using a tuple.

# %%
# TODO: Implement Solution for Question 107

# %% [markdown]
# ### **Question 108** *(Topic 5.8)*
# > How do you use the nonlocal keyword inside a nested function?

# %%
# TODO: Implement Solution for Question 108

# %% [markdown]
# ### **Question 109** *(Topic 5.9)*
# > Write a Python program to compute the factorial of a number using recursion.

# %%
# TODO: Implement Solution for Question 109

# %% [markdown]
# ### **Question 110** *(Topic 5.10)*
# > How do you define and call a lambda function to square a number?

# %%
# TODO: Implement Solution for Question 110

# %% [markdown]
# ### **Question 111** *(Topic 5.11)*
# > Write a Python program to demonstrate a higher-order function that takes a function as an argument.

# %%
# TODO: Implement Solution for Question 111

# %% [markdown]
# ### **Question 112** *(Topic 5.12)*
# > How do you use map() to apply a function to every element of a list?

# %%
# TODO: Implement Solution for Question 112

# %% [markdown]
# ### **Question 113** *(Topic 5.13)*
# > Write a Python program to use filter() to extract even numbers from a list.

# %%
# TODO: Implement Solution for Question 113

# %% [markdown]
# ### **Question 114** *(Topic 5.14)*
# > How do you use functools.reduce() to compute the product of a list of numbers?

# %%
# TODO: Implement Solution for Question 114

# %% [markdown]
# ### **Question 115** *(Topic 5.15)*
# > Write a Python function to find the nth Fibonacci number using memoization with a dictionary.

# %%
# TODO: Implement Solution for Question 115

# %% [markdown]
# ### **Question 116** *(Topic 5.16)*
# > How do you create a closure in Python and explain when to use it?

# %%
# TODO: Implement Solution for Question 116

# %% [markdown]
# ### **Question 117** *(Topic 5.17)*
# > Write a Python program to implement a recursive function to flatten a nested list.

# %%
# TODO: Implement Solution for Question 117

# %% [markdown]
# ### **Question 118** *(Topic 5.18)*
# > How do you annotate function parameters and return types using Python type hints?

# %%
# TODO: Implement Solution for Question 118

# %% [markdown]
# ### **Question 119** *(Topic 5.19)*
# > Write a Python program to implement a decorator that logs function call details.

# %%
# TODO: Implement Solution for Question 119

# %% [markdown]
# ### **Question 120** *(Topic 5.20)*
# > How do you use functools.lru_cache to speed up a recursive Fibonacci function?

# %%
# TODO: Implement Solution for Question 120

# %% [markdown]
# ### **Question 121** *(Topic 5.21)*
# > Write a Python function that accepts any mix of positional and keyword arguments.

# %%
# TODO: Implement Solution for Question 121

# %% [markdown]
# ### **Question 122** *(Topic 5.22)*
# > How do you inspect a function's docstring using the __doc__ attribute and help()?

# %%
# TODO: Implement Solution for Question 122

# %% [markdown]
# ### **Question 123** *(Topic 5.23)*
# > Write a Python program to demonstrate partial function application using functools.partial.

# %%
# TODO: Implement Solution for Question 123

# %% [markdown]
# ### **Question 124** *(Topic 5.24)*
# > How do you write a generator function using yield to generate an infinite sequence?

# %%
# TODO: Implement Solution for Question 124

# %% [markdown]
# ### **Question 125** *(Topic 5.25)*
# > Write a Python program to implement a recursive binary search function.

# %%
# TODO: Implement Solution for Question 125

# %% [markdown]
# ## Level 6: Topic 6: Strings — Methods, Slicing & Formatting
# ---

# %% [markdown]
# ### **Question 126** *(Topic 6.1)*
# > Write a Python program to reverse a string without using slicing.

# %%
# TODO: Implement Solution for Question 126

# %% [markdown]
# ### **Question 127** *(Topic 6.2)*
# > How do you check if a string is a palindrome?

# %%
# TODO: Implement Solution for Question 127

# %% [markdown]
# ### **Question 128** *(Topic 6.3)*
# > Write a Python program to count the occurrences of each character in a string.

# %%
# TODO: Implement Solution for Question 128

# %% [markdown]
# ### **Question 129** *(Topic 6.4)*
# > How do you split a sentence into words and rejoin them with a different separator?

# %%
# TODO: Implement Solution for Question 129

# %% [markdown]
# ### **Question 130** *(Topic 6.5)*
# > Write a Python program to check if two strings are anagrams.

# %%
# TODO: Implement Solution for Question 130

# %% [markdown]
# ### **Question 131** *(Topic 6.6)*
# > How do you remove all punctuation from a string using str methods?

# %%
# TODO: Implement Solution for Question 131

# %% [markdown]
# ### **Question 132** *(Topic 6.7)*
# > Write a Python program to find the longest word in a sentence.

# %%
# TODO: Implement Solution for Question 132

# %% [markdown]
# ### **Question 133** *(Topic 6.8)*
# > How do you use str.replace() to remove all spaces from a string?

# %%
# TODO: Implement Solution for Question 133

# %% [markdown]
# ### **Question 134** *(Topic 6.9)*
# > Write a Python program to capitalize the first letter of every word using title() and manually.

# %%
# TODO: Implement Solution for Question 134

# %% [markdown]
# ### **Question 135** *(Topic 6.10)*
# > How do you check if a string starts or ends with a specific substring?

# %%
# TODO: Implement Solution for Question 135

# %% [markdown]
# ### **Question 136** *(Topic 6.11)*
# > Write a Python program to extract all digits from a string using isdigit().

# %%
# TODO: Implement Solution for Question 136

# %% [markdown]
# ### **Question 137** *(Topic 6.12)*
# > How do you format a float to 2 decimal places in a string using f-strings?

# %%
# TODO: Implement Solution for Question 137

# %% [markdown]
# ### **Question 138** *(Topic 6.13)*
# > Write a Python program to find all occurrences of a substring in a string using a loop.

# %%
# TODO: Implement Solution for Question 138

# %% [markdown]
# ### **Question 139** *(Topic 6.14)*
# > How do you align text (left, right, center) using str.ljust(), rjust(), and center()?

# %%
# TODO: Implement Solution for Question 139

# %% [markdown]
# ### **Question 140** *(Topic 6.15)*
# > Write a Python program to count vowels in a string (case-insensitive).

# %%
# TODO: Implement Solution for Question 140

# %% [markdown]
# ### **Question 141** *(Topic 6.16)*
# > How do you convert a string to a list of characters and back?

# %%
# TODO: Implement Solution for Question 141

# %% [markdown]
# ### **Question 142** *(Topic 6.17)*
# > Write a Python program to compress a string using run-length encoding (e.g., 'aaabb' -> 'a3b2').

# %%
# TODO: Implement Solution for Question 142

# %% [markdown]
# ### **Question 143** *(Topic 6.18)*
# > How do you use string slicing to extract every other character from a string?

# %%
# TODO: Implement Solution for Question 143

# %% [markdown]
# ### **Question 144** *(Topic 6.19)*
# > Write a Python program to check if a string contains only alphabetic characters.

# %%
# TODO: Implement Solution for Question 144

# %% [markdown]
# ### **Question 145** *(Topic 6.20)*
# > How do you use textwrap.wrap() to wrap a long string at a given width?

# %%
# TODO: Implement Solution for Question 145

# %% [markdown]
# ### **Question 146** *(Topic 6.21)*
# > Write a Python program to reverse the order of words in a sentence.

# %%
# TODO: Implement Solution for Question 146

# %% [markdown]
# ### **Question 147** *(Topic 6.22)*
# > How do you strip leading/trailing whitespace and specific characters from a string?

# %%
# TODO: Implement Solution for Question 147

# %% [markdown]
# ### **Question 148** *(Topic 6.23)*
# > Write a Python program to find the most frequently occurring character in a string.

# %%
# TODO: Implement Solution for Question 148

# %% [markdown]
# ### **Question 149** *(Topic 6.24)*
# > How do you use the encode() and decode() methods to handle string bytes?

# %%
# TODO: Implement Solution for Question 149

# %% [markdown]
# ### **Question 150** *(Topic 6.25)*
# > Write a Python program to validate an email address format using string methods.

# %%
# TODO: Implement Solution for Question 150

# %% [markdown]
# ## Level 7: Topic 7: Lists & List Comprehensions
# ---

# %% [markdown]
# ### **Question 151** *(Topic 7.1)*
# > Write a Python program to find the second largest element in a list.

# %%
# TODO: Implement Solution for Question 151

# %% [markdown]
# ### **Question 152** *(Topic 7.2)*
# > How do you remove duplicate elements from a list while preserving order?

# %%
# TODO: Implement Solution for Question 152

# %% [markdown]
# ### **Question 153** *(Topic 7.3)*
# > Write a Python program to flatten a list of lists using list comprehension.

# %%
# TODO: Implement Solution for Question 153

# %% [markdown]
# ### **Question 154** *(Topic 7.4)*
# > How do you rotate a list by k positions to the right?

# %%
# TODO: Implement Solution for Question 154

# %% [markdown]
# ### **Question 155** *(Topic 7.5)*
# > Write a Python program to merge two sorted lists into one sorted list.

# %%
# TODO: Implement Solution for Question 155

# %% [markdown]
# ### **Question 156** *(Topic 7.6)*
# > How do you use list slicing to reverse a list?

# %%
# TODO: Implement Solution for Question 156

# %% [markdown]
# ### **Question 157** *(Topic 7.7)*
# > Write a Python program to split a list into chunks of size n.

# %%
# TODO: Implement Solution for Question 157

# %% [markdown]
# ### **Question 158** *(Topic 7.8)*
# > How do you find all common elements between two lists?

# %%
# TODO: Implement Solution for Question 158

# %% [markdown]
# ### **Question 159** *(Topic 7.9)*
# > Write a Python program to find elements in list A that are not in list B.

# %%
# TODO: Implement Solution for Question 159

# %% [markdown]
# ### **Question 160** *(Topic 7.10)*
# > How do you sort a list of dictionaries by a specific key?

# %%
# TODO: Implement Solution for Question 160

# %% [markdown]
# ### **Question 161** *(Topic 7.11)*
# > Write a Python program to find the cumulative sum of a list.

# %%
# TODO: Implement Solution for Question 161

# %% [markdown]
# ### **Question 162** *(Topic 7.12)*
# > How do you use a list comprehension to generate squares of odd numbers up to 50?

# %%
# TODO: Implement Solution for Question 162

# %% [markdown]
# ### **Question 163** *(Topic 7.13)*
# > Write a Python program to count how many times each element appears in a list.

# %%
# TODO: Implement Solution for Question 163

# %% [markdown]
# ### **Question 164** *(Topic 7.14)*
# > How do you remove all falsy values (0, None, '', False) from a list?

# %%
# TODO: Implement Solution for Question 164

# %% [markdown]
# ### **Question 165** *(Topic 7.15)*
# > Write a Python program to transpose a matrix represented as a list of lists.

# %%
# TODO: Implement Solution for Question 165

# %% [markdown]
# ### **Question 166** *(Topic 7.16)*
# > How do you zip two lists together into a list of tuples?

# %%
# TODO: Implement Solution for Question 166

# %% [markdown]
# ### **Question 167** *(Topic 7.17)*
# > Write a Python program to find the intersection and union of two lists.

# %%
# TODO: Implement Solution for Question 167

# %% [markdown]
# ### **Question 168** *(Topic 7.18)*
# > How do you create a list of tuples from two parallel lists using zip()?

# %%
# TODO: Implement Solution for Question 168

# %% [markdown]
# ### **Question 169** *(Topic 7.19)*
# > Write a Python program to insert an element at a specific position in a list.

# %%
# TODO: Implement Solution for Question 169

# %% [markdown]
# ### **Question 170** *(Topic 7.20)*
# > How do you use bisect to insert a number into a sorted list at the correct position?

# %%
# TODO: Implement Solution for Question 170

# %% [markdown]
# ### **Question 171** *(Topic 7.21)*
# > Write a Python program to find the missing number in a list of 1 to n.

# %%
# TODO: Implement Solution for Question 171

# %% [markdown]
# ### **Question 172** *(Topic 7.22)*
# > How do you use enumerate() and list comprehension to create an index-value pair list?

# %%
# TODO: Implement Solution for Question 172

# %% [markdown]
# ### **Question 173** *(Topic 7.23)*
# > Write a Python program to group a list of elements into sublists based on a condition.

# %%
# TODO: Implement Solution for Question 173

# %% [markdown]
# ### **Question 174** *(Topic 7.24)*
# > How do you compare two lists for equality and find differing elements?

# %%
# TODO: Implement Solution for Question 174

# %% [markdown]
# ### **Question 175** *(Topic 7.25)*
# > Write a Python program to implement bubble sort and selection sort on a list.

# %%
# TODO: Implement Solution for Question 175

# %% [markdown]
# ## Level 8: Topic 8: Tuples, Sets & Frozensets
# ---

# %% [markdown]
# ### **Question 176** *(Topic 8.1)*
# > Write a Python program to unpack a tuple into individual variables.

# %%
# TODO: Implement Solution for Question 176

# %% [markdown]
# ### **Question 177** *(Topic 8.2)*
# > How do you use a tuple as a dictionary key and explain why lists cannot be used?

# %%
# TODO: Implement Solution for Question 177

# %% [markdown]
# ### **Question 178** *(Topic 8.3)*
# > Write a Python program to swap two variables using tuple packing and unpacking.

# %%
# TODO: Implement Solution for Question 178

# %% [markdown]
# ### **Question 179** *(Topic 8.4)*
# > How do you find the index and count of an element in a tuple?

# %%
# TODO: Implement Solution for Question 179

# %% [markdown]
# ### **Question 180** *(Topic 8.5)*
# > Write a Python program to convert a list of tuples into a dictionary.

# %%
# TODO: Implement Solution for Question 180

# %% [markdown]
# ### **Question 181** *(Topic 8.6)*
# > How do you use a named tuple from the collections module?

# %%
# TODO: Implement Solution for Question 181

# %% [markdown]
# ### **Question 182** *(Topic 8.7)*
# > Write a Python program to find all unique elements across two lists using sets.

# %%
# TODO: Implement Solution for Question 182

# %% [markdown]
# ### **Question 183** *(Topic 8.8)*
# > How do you compute the union, intersection, difference, and symmetric difference of two sets?

# %%
# TODO: Implement Solution for Question 183

# %% [markdown]
# ### **Question 184** *(Topic 8.9)*
# > Write a Python program to check if one set is a subset or superset of another.

# %%
# TODO: Implement Solution for Question 184

# %% [markdown]
# ### **Question 185** *(Topic 8.10)*
# > How do you use a set to remove duplicates from a list?

# %%
# TODO: Implement Solution for Question 185

# %% [markdown]
# ### **Question 186** *(Topic 8.11)*
# > Write a Python program to find common elements in three sets.

# %%
# TODO: Implement Solution for Question 186

# %% [markdown]
# ### **Question 187** *(Topic 8.12)*
# > How do you iterate over a set and explain why the order is not guaranteed?

# %%
# TODO: Implement Solution for Question 187

# %% [markdown]
# ### **Question 188** *(Topic 8.13)*
# > Write a Python program to convert a frozenset to a set and vice versa.

# %%
# TODO: Implement Solution for Question 188

# %% [markdown]
# ### **Question 189** *(Topic 8.14)*
# > How do you use a frozenset as a dictionary key?

# %%
# TODO: Implement Solution for Question 189

# %% [markdown]
# ### **Question 190** *(Topic 8.15)*
# > Write a Python program to find the symmetric difference between two sets using ^ and the method.

# %%
# TODO: Implement Solution for Question 190

# %% [markdown]
# ### **Question 191** *(Topic 8.16)*
# > How do you check membership in a set vs a list and compare their time complexity?

# %%
# TODO: Implement Solution for Question 191

# %% [markdown]
# ### **Question 192** *(Topic 8.17)*
# > Write a Python program to generate all subsets of a given set using loops.

# %%
# TODO: Implement Solution for Question 192

# %% [markdown]
# ### **Question 193** *(Topic 8.18)*
# > How do you use set comprehension to build a set of squared values?

# %%
# TODO: Implement Solution for Question 193

# %% [markdown]
# ### **Question 194** *(Topic 8.19)*
# > Write a Python program to count the number of unique words in a paragraph using a set.

# %%
# TODO: Implement Solution for Question 194

# %% [markdown]
# ### **Question 195** *(Topic 8.20)*
# > How do you sort a set and explain what data structure is returned?

# %%
# TODO: Implement Solution for Question 195

# %% [markdown]
# ### **Question 196** *(Topic 8.21)*
# > Write a Python program to find elements present in the first set but not the second (difference).

# %%
# TODO: Implement Solution for Question 196

# %% [markdown]
# ### **Question 197** *(Topic 8.22)*
# > How do you update a set in place using update() and |=?

# %%
# TODO: Implement Solution for Question 197

# %% [markdown]
# ### **Question 198** *(Topic 8.23)*
# > Write a Python program to demonstrate that sets are mutable while frozensets are immutable.

# %%
# TODO: Implement Solution for Question 198

# %% [markdown]
# ### **Question 199** *(Topic 8.24)*
# > How do you use a set to implement a simple spell checker against a vocabulary list?

# %%
# TODO: Implement Solution for Question 199

# %% [markdown]
# ### **Question 200** *(Topic 8.25)*
# > Write a Python program to find all pairs of elements in a list that sum to a target using sets.

# %%
# TODO: Implement Solution for Question 200

# %% [markdown]
# ## Level 9: Topic 9: Dictionaries
# ---

# %% [markdown]
# ### **Question 201** *(Topic 9.1)*
# > Write a Python program to count the frequency of each word in a sentence using a dictionary.

# %%
# TODO: Implement Solution for Question 201

# %% [markdown]
# ### **Question 202** *(Topic 9.2)*
# > How do you merge two dictionaries using the | operator and update()?

# %%
# TODO: Implement Solution for Question 202

# %% [markdown]
# ### **Question 203** *(Topic 9.3)*
# > Write a Python program to invert a dictionary (swap keys and values).

# %%
# TODO: Implement Solution for Question 203

# %% [markdown]
# ### **Question 204** *(Topic 9.4)*
# > How do you use dict.get() with a default value to avoid KeyError?

# %%
# TODO: Implement Solution for Question 204

# %% [markdown]
# ### **Question 205** *(Topic 9.5)*
# > Write a Python program to sort a dictionary by its values in descending order.

# %%
# TODO: Implement Solution for Question 205

# %% [markdown]
# ### **Question 206** *(Topic 9.6)*
# > How do you use defaultdict from the collections module?

# %%
# TODO: Implement Solution for Question 206

# %% [markdown]
# ### **Question 207** *(Topic 9.7)*
# > Write a Python program to group a list of words by their first letter using a dictionary.

# %%
# TODO: Implement Solution for Question 207

# %% [markdown]
# ### **Question 208** *(Topic 9.8)*
# > How do you use Counter from collections to find the most common elements?

# %%
# TODO: Implement Solution for Question 208

# %% [markdown]
# ### **Question 209** *(Topic 9.9)*
# > Write a Python program to build a nested dictionary representing a student's marks in subjects.

# %%
# TODO: Implement Solution for Question 209

# %% [markdown]
# ### **Question 210** *(Topic 9.10)*
# > How do you iterate over a dictionary to print formatted key-value pairs?

# %%
# TODO: Implement Solution for Question 210

# %% [markdown]
# ### **Question 211** *(Topic 9.11)*
# > Write a Python program to find all keys whose values are greater than a threshold.

# %%
# TODO: Implement Solution for Question 211

# %% [markdown]
# ### **Question 212** *(Topic 9.12)*
# > How do you use dict comprehension to create a dictionary of squares from 1 to 10?

# %%
# TODO: Implement Solution for Question 212

# %% [markdown]
# ### **Question 213** *(Topic 9.13)*
# > Write a Python program to flatten a nested dictionary into a single-level dictionary.

# %%
# TODO: Implement Solution for Question 213

# %% [markdown]
# ### **Question 214** *(Topic 9.14)*
# > How do you safely remove a key from a dictionary using pop() and del?

# %%
# TODO: Implement Solution for Question 214

# %% [markdown]
# ### **Question 215** *(Topic 9.15)*
# > Write a Python program to find the key with the maximum value in a dictionary.

# %%
# TODO: Implement Solution for Question 215

# %% [markdown]
# ### **Question 216** *(Topic 9.16)*
# > How do you use OrderedDict from collections and explain when it matters?

# %%
# TODO: Implement Solution for Question 216

# %% [markdown]
# ### **Question 217** *(Topic 9.17)*
# > Write a Python program to check if two dictionaries have the same keys.

# %%
# TODO: Implement Solution for Question 217

# %% [markdown]
# ### **Question 218** *(Topic 9.18)*
# > How do you implement a word frequency counter and print the top 5 words?

# %%
# TODO: Implement Solution for Question 218

# %% [markdown]
# ### **Question 219** *(Topic 9.19)*
# > Write a Python program to merge a list of dictionaries into one dictionary.

# %%
# TODO: Implement Solution for Question 219

# %% [markdown]
# ### **Question 220** *(Topic 9.20)*
# > How do you convert two lists (keys and values) into a dictionary using zip()?

# %%
# TODO: Implement Solution for Question 220

# %% [markdown]
# ### **Question 221** *(Topic 9.21)*
# > Write a Python program to build an inverted index: word -> list of sentence indices.

# %%
# TODO: Implement Solution for Question 221

# %% [markdown]
# ### **Question 222** *(Topic 9.22)*
# > How do you use ChainMap to combine multiple dictionaries for lookup?

# %%
# TODO: Implement Solution for Question 222

# %% [markdown]
# ### **Question 223** *(Topic 9.23)*
# > Write a Python program to copy a dictionary shallowly and deeply and show the difference.

# %%
# TODO: Implement Solution for Question 223

# %% [markdown]
# ### **Question 224** *(Topic 9.24)*
# > How do you use setdefault() to safely initialize nested dictionary entries?

# %%
# TODO: Implement Solution for Question 224

# %% [markdown]
# ### **Question 225** *(Topic 9.25)*
# > Write a Python program to compute the sum of all values in a nested dictionary.

# %%
# TODO: Implement Solution for Question 225

# %% [markdown]
# ## Level 10: Topic 10: File Handling
# ---

# %% [markdown]
# ### **Question 226** *(Topic 10.1)*
# > Write a Python program to create a text file and write multiple lines to it.

# %%
# TODO: Implement Solution for Question 226

# %% [markdown]
# ### **Question 227** *(Topic 10.2)*
# > How do you read an entire file content at once using read()?

# %%
# TODO: Implement Solution for Question 227

# %% [markdown]
# ### **Question 228** *(Topic 10.3)*
# > Write a Python program to read a file line by line and count the total number of lines.

# %%
# TODO: Implement Solution for Question 228

# %% [markdown]
# ### **Question 229** *(Topic 10.4)*
# > How do you append new content to an existing file without overwriting it?

# %%
# TODO: Implement Solution for Question 229

# %% [markdown]
# ### **Question 230** *(Topic 10.5)*
# > Write a Python program to count the number of words in a text file.

# %%
# TODO: Implement Solution for Question 230

# %% [markdown]
# ### **Question 231** *(Topic 10.6)*
# > How do you use the with statement to ensure a file is properly closed?

# %%
# TODO: Implement Solution for Question 231

# %% [markdown]
# ### **Question 232** *(Topic 10.7)*
# > Write a Python program to copy the contents of one file to another.

# %%
# TODO: Implement Solution for Question 232

# %% [markdown]
# ### **Question 233** *(Topic 10.8)*
# > How do you read and write CSV files using the csv module?

# %%
# TODO: Implement Solution for Question 233

# %% [markdown]
# ### **Question 234** *(Topic 10.9)*
# > Write a Python program to find and replace a word in a text file.

# %%
# TODO: Implement Solution for Question 234

# %% [markdown]
# ### **Question 235** *(Topic 10.10)*
# > How do you write a list of dictionaries to a CSV file using csv.DictWriter?

# %%
# TODO: Implement Solution for Question 235

# %% [markdown]
# ### **Question 236** *(Topic 10.11)*
# > Write a Python program to read a JSON file, modify a field, and write it back.

# %%
# TODO: Implement Solution for Question 236

# %% [markdown]
# ### **Question 237** *(Topic 10.12)*
# > How do you use os.path to check if a file exists before opening it?

# %%
# TODO: Implement Solution for Question 237

# %% [markdown]
# ### **Question 238** *(Topic 10.13)*
# > Write a Python program to list all files in a directory with their sizes using os.

# %%
# TODO: Implement Solution for Question 238

# %% [markdown]
# ### **Question 239** *(Topic 10.14)*
# > How do you delete a file and a directory safely using os.remove() and shutil.rmtree()?

# %%
# TODO: Implement Solution for Question 239

# %% [markdown]
# ### **Question 240** *(Topic 10.15)*
# > Write a Python program to read a binary file and display its bytes in hex format.

# %%
# TODO: Implement Solution for Question 240

# %% [markdown]
# ### **Question 241** *(Topic 10.16)*
# > How do you use pickle to serialize and deserialize a Python object to/from a file?

# %%
# TODO: Implement Solution for Question 241

# %% [markdown]
# ### **Question 242** *(Topic 10.17)*
# > Write a Python program to search for all lines containing a specific keyword in a file.

# %%
# TODO: Implement Solution for Question 242

# %% [markdown]
# ### **Question 243** *(Topic 10.18)*
# > How do you rename and move files using os.rename() and shutil.move()?

# %%
# TODO: Implement Solution for Question 243

# %% [markdown]
# ### **Question 244** *(Topic 10.19)*
# > Write a Python program to merge the contents of multiple text files into one.

# %%
# TODO: Implement Solution for Question 244

# %% [markdown]
# ### **Question 245** *(Topic 10.20)*
# > How do you write a log file with timestamps for each event using the logging module?

# %%
# TODO: Implement Solution for Question 245

# %% [markdown]
# ### **Question 246** *(Topic 10.21)*
# > Write a Python program to read a file in chunks to handle large files efficiently.

# %%
# TODO: Implement Solution for Question 246

# %% [markdown]
# ### **Question 247** *(Topic 10.22)*
# > How do you use pathlib.Path to perform file and directory operations?

# %%
# TODO: Implement Solution for Question 247

# %% [markdown]
# ### **Question 248** *(Topic 10.23)*
# > Write a Python program to zip multiple files into a zip archive using zipfile.

# %%
# TODO: Implement Solution for Question 248

# %% [markdown]
# ### **Question 249** *(Topic 10.24)*
# > How do you read and process a .csv file with pandas (or csv module if pandas unavailable)?

# %%
# TODO: Implement Solution for Question 249

# %% [markdown]
# ### **Question 250** *(Topic 10.25)*
# > Write a Python program to count character, word, and line frequencies in a text file.

# %%
# TODO: Implement Solution for Question 250

# %% [markdown]
# ## Level 11: Topic 11: Exception Handling
# ---

# %% [markdown]
# ### **Question 251** *(Topic 11.1)*
# > Write a Python program that catches a ZeroDivisionError and prints a user-friendly message.

# %%
# TODO: Implement Solution for Question 251

# %% [markdown]
# ### **Question 252** *(Topic 11.2)*
# > How do you use try-except-else-finally to manage file reading errors?

# %%
# TODO: Implement Solution for Question 252

# %% [markdown]
# ### **Question 253** *(Topic 11.3)*
# > Write a Python program to handle ValueError when converting user input to an integer.

# %%
# TODO: Implement Solution for Question 253

# %% [markdown]
# ### **Question 254** *(Topic 11.4)*
# > How do you catch multiple exceptions in a single except block?

# %%
# TODO: Implement Solution for Question 254

# %% [markdown]
# ### **Question 255** *(Topic 11.5)*
# > Write a Python program to demonstrate raising a custom exception.

# %%
# TODO: Implement Solution for Question 255

# %% [markdown]
# ### **Question 256** *(Topic 11.6)*
# > How do you define a custom exception class inheriting from Exception?

# %%
# TODO: Implement Solution for Question 256

# %% [markdown]
# ### **Question 257** *(Topic 11.7)*
# > Write a Python program to use the finally block to ensure a database connection is closed.

# %%
# TODO: Implement Solution for Question 257

# %% [markdown]
# ### **Question 258** *(Topic 11.8)*
# > How do you use assert to validate function preconditions and handle AssertionError?

# %%
# TODO: Implement Solution for Question 258

# %% [markdown]
# ### **Question 259** *(Topic 11.9)*
# > Write a Python program to re-raise an exception after logging it.

# %%
# TODO: Implement Solution for Question 259

# %% [markdown]
# ### **Question 260** *(Topic 11.10)*
# > How do you use the else clause in a try block and when does it execute?

# %%
# TODO: Implement Solution for Question 260

# %% [markdown]
# ### **Question 261** *(Topic 11.11)*
# > Write a Python program to build a robust input loop that retries on invalid input.

# %%
# TODO: Implement Solution for Question 261

# %% [markdown]
# ### **Question 262** *(Topic 11.12)*
# > How do you chain exceptions using raise ... from ... for better error context?

# %%
# TODO: Implement Solution for Question 262

# %% [markdown]
# ### **Question 263** *(Topic 11.13)*
# > Write a Python program to handle FileNotFoundError and IOError during file operations.

# %%
# TODO: Implement Solution for Question 263

# %% [markdown]
# ### **Question 264** *(Topic 11.14)*
# > How do you use contextlib.suppress to silently ignore specific exceptions?

# %%
# TODO: Implement Solution for Question 264

# %% [markdown]
# ### **Question 265** *(Topic 11.15)*
# > Write a Python program to validate a list of numbers and collect all errors before raising.

# %%
# TODO: Implement Solution for Question 265

# %% [markdown]
# ### **Question 266** *(Topic 11.16)*
# > How do you capture the exception object and inspect its message and type?

# %%
# TODO: Implement Solution for Question 266

# %% [markdown]
# ### **Question 267** *(Topic 11.17)*
# > Write a Python program to implement a retry mechanism using a loop and exception handling.

# %%
# TODO: Implement Solution for Question 267

# %% [markdown]
# ### **Question 268** *(Topic 11.18)*
# > How do you use the warnings module to issue non-fatal warnings?

# %%
# TODO: Implement Solution for Question 268

# %% [markdown]
# ### **Question 269** *(Topic 11.19)*
# > Write a Python program to demonstrate the exception hierarchy and catch a parent exception.

# %%
# TODO: Implement Solution for Question 269

# %% [markdown]
# ### **Question 270** *(Topic 11.20)*
# > How do you handle RecursionError by setting a recursion limit with sys.setrecursionlimit()?

# %%
# TODO: Implement Solution for Question 270

# %% [markdown]
# ### **Question 271** *(Topic 11.21)*
# > Write a Python program to use exception handling to parse and validate a date string.

# %%
# TODO: Implement Solution for Question 271

# %% [markdown]
# ### **Question 272** *(Topic 11.22)*
# > How do you handle KeyError and IndexError in dictionary and list access safely?

# %%
# TODO: Implement Solution for Question 272

# %% [markdown]
# ### **Question 273** *(Topic 11.23)*
# > Write a Python program to demonstrate exception handling in a REST API response parser.

# %%
# TODO: Implement Solution for Question 273

# %% [markdown]
# ### **Question 274** *(Topic 11.24)*
# > How do you log exceptions with traceback information using the logging module?

# %%
# TODO: Implement Solution for Question 274

# %% [markdown]
# ### **Question 275** *(Topic 11.25)*
# > Write a Python program to build a safe calculator that handles all arithmetic exceptions.

# %%
# TODO: Implement Solution for Question 275

# %% [markdown]
# ## Level 12: Topic 12: Object-Oriented Programming — Classes & Objects
# ---

# %% [markdown]
# ### **Question 276** *(Topic 12.1)*
# > Write a Python class BankAccount with attributes owner and balance, and methods deposit() and withdraw().

# %%
# TODO: Implement Solution for Question 276

# %% [markdown]
# ### **Question 277** *(Topic 12.2)*
# > How do you implement the __str__ and __repr__ methods in a class?

# %%
# TODO: Implement Solution for Question 277

# %% [markdown]
# ### **Question 278** *(Topic 12.3)*
# > Write a Python program to implement a class Student with class variables and instance variables.

# %%
# TODO: Implement Solution for Question 278

# %% [markdown]
# ### **Question 279** *(Topic 12.4)*
# > How do you use @property to create a getter and setter for a private attribute?

# %%
# TODO: Implement Solution for Question 279

# %% [markdown]
# ### **Question 280** *(Topic 12.5)*
# > Write a Python program to implement inheritance: a base class Animal with subclasses Dog and Cat.

# %%
# TODO: Implement Solution for Question 280

# %% [markdown]
# ### **Question 281** *(Topic 12.6)*
# > How do you use super() to call a parent class method in a subclass?

# %%
# TODO: Implement Solution for Question 281

# %% [markdown]
# ### **Question 282** *(Topic 12.7)*
# > Write a Python program to demonstrate method overriding in a subclass.

# %%
# TODO: Implement Solution for Question 282

# %% [markdown]
# ### **Question 283** *(Topic 12.8)*
# > How do you implement multiple inheritance in Python and resolve method resolution order (MRO)?

# %%
# TODO: Implement Solution for Question 283

# %% [markdown]
# ### **Question 284** *(Topic 12.9)*
# > Write a Python program to implement a class with @classmethod and @staticmethod.

# %%
# TODO: Implement Solution for Question 284

# %% [markdown]
# ### **Question 285** *(Topic 12.10)*
# > How do you implement operator overloading for + and == in a custom Vector class?

# %%
# TODO: Implement Solution for Question 285

# %% [markdown]
# ### **Question 286** *(Topic 12.11)*
# > Write a Python program to create a class with __len__, __getitem__, and __iter__ to make it iterable.

# %%
# TODO: Implement Solution for Question 286

# %% [markdown]
# ### **Question 287** *(Topic 12.12)*
# > How do you implement a Singleton design pattern in Python?

# %%
# TODO: Implement Solution for Question 287

# %% [markdown]
# ### **Question 288** *(Topic 12.13)*
# > Write a Python program to use __slots__ to restrict attributes and improve memory usage.

# %%
# TODO: Implement Solution for Question 288

# %% [markdown]
# ### **Question 289** *(Topic 12.14)*
# > How do you implement the __enter__ and __exit__ methods to use a class as a context manager?

# %%
# TODO: Implement Solution for Question 289

# %% [markdown]
# ### **Question 290** *(Topic 12.15)*
# > Write a Python program to demonstrate abstract classes using the abc module.

# %%
# TODO: Implement Solution for Question 290

# %% [markdown]
# ### **Question 291** *(Topic 12.16)*
# > How do you implement polymorphism using duck typing?

# %%
# TODO: Implement Solution for Question 291

# %% [markdown]
# ### **Question 292** *(Topic 12.17)*
# > Write a Python program to implement a class hierarchy for geometric shapes (Circle, Rectangle, Triangle) with an area() method.

# %%
# TODO: Implement Solution for Question 292

# %% [markdown]
# ### **Question 293** *(Topic 12.18)*
# > How do you implement a mixin class to add logging behavior to multiple classes?

# %%
# TODO: Implement Solution for Question 293

# %% [markdown]
# ### **Question 294** *(Topic 12.19)*
# > Write a Python program to implement the __eq__, __lt__, and __gt__ methods for object comparison.

# %%
# TODO: Implement Solution for Question 294

# %% [markdown]
# ### **Question 295** *(Topic 12.20)*
# > How do you use dataclasses to automatically generate __init__, __repr__, and __eq__?

# %%
# TODO: Implement Solution for Question 295

# %% [markdown]
# ### **Question 296** *(Topic 12.21)*
# > Write a Python program to implement composition vs. inheritance with a Car class using an Engine class.

# %%
# TODO: Implement Solution for Question 296

# %% [markdown]
# ### **Question 297** *(Topic 12.22)*
# > How do you use __call__ to make an object callable?

# %%
# TODO: Implement Solution for Question 297

# %% [markdown]
# ### **Question 298** *(Topic 12.23)*
# > Write a Python program to implement the iterator protocol (__iter__ and __next__) in a custom class.

# %%
# TODO: Implement Solution for Question 298

# %% [markdown]
# ### **Question 299** *(Topic 12.24)*
# > How do you implement deep copy vs. shallow copy for a custom class?

# %%
# TODO: Implement Solution for Question 299

# %% [markdown]
# ### **Question 300** *(Topic 12.25)*
# > Write a Python program to demonstrate encapsulation with name mangling using double underscore attributes.

# %%
# TODO: Implement Solution for Question 300

# %% [markdown]
# ## Level 13: Topic 13: Modules, Packages & Standard Library
# ---

# %% [markdown]
# ### **Question 301** *(Topic 13.1)*
# > Write a Python program to create a module with utility functions and import it in another script.

# %%
# TODO: Implement Solution for Question 301

# %% [markdown]
# ### **Question 302** *(Topic 13.2)*
# > How do you use the math module to compute sqrt, ceil, floor, log, and factorial?

# %%
# TODO: Implement Solution for Question 302

# %% [markdown]
# ### **Question 303** *(Topic 13.3)*
# > Write a Python program to generate random numbers, shuffle a list, and pick a random sample using random.

# %%
# TODO: Implement Solution for Question 303

# %% [markdown]
# ### **Question 304** *(Topic 13.4)*
# > How do you use the datetime module to get the current date/time, format it, and calculate date differences?

# %%
# TODO: Implement Solution for Question 304

# %% [markdown]
# ### **Question 305** *(Topic 13.5)*
# > Write a Python program to use the os module to get the current directory, list files, and create directories.

# %%
# TODO: Implement Solution for Question 305

# %% [markdown]
# ### **Question 306** *(Topic 13.6)*
# > How do you use sys.argv to accept command-line arguments?

# %%
# TODO: Implement Solution for Question 306

# %% [markdown]
# ### **Question 307** *(Topic 13.7)*
# > Write a Python program to use the re module to validate a phone number pattern.

# %%
# TODO: Implement Solution for Question 307

# %% [markdown]
# ### **Question 308** *(Topic 13.8)*
# > How do you use collections.Counter, defaultdict, deque, and OrderedDict with examples?

# %%
# TODO: Implement Solution for Question 308

# %% [markdown]
# ### **Question 309** *(Topic 13.9)*
# > Write a Python program to use itertools.product, permutations, combinations, and chain.

# %%
# TODO: Implement Solution for Question 309

# %% [markdown]
# ### **Question 310** *(Topic 13.10)*
# > How do you use functools.partial, reduce, and lru_cache?

# %%
# TODO: Implement Solution for Question 310

# %% [markdown]
# ### **Question 311** *(Topic 13.11)*
# > Write a Python program to use the json module to serialize/deserialize Python objects.

# %%
# TODO: Implement Solution for Question 311

# %% [markdown]
# ### **Question 312** *(Topic 13.12)*
# > How do you use the csv module to read/write CSV files?

# %%
# TODO: Implement Solution for Question 312

# %% [markdown]
# ### **Question 313** *(Topic 13.13)*
# > Write a Python program to use time.time(), time.sleep(), and timeit to measure execution time.

# %%
# TODO: Implement Solution for Question 313

# %% [markdown]
# ### **Question 314** *(Topic 13.14)*
# > How do you use argparse to build a command-line tool with flags and arguments?

# %%
# TODO: Implement Solution for Question 314

# %% [markdown]
# ### **Question 315** *(Topic 13.15)*
# > Write a Python program to use glob to search for files matching a pattern in a directory.

# %%
# TODO: Implement Solution for Question 315

# %% [markdown]
# ### **Question 316** *(Topic 13.16)*
# > How do you use the hashlib module to compute MD5 and SHA256 hashes?

# %%
# TODO: Implement Solution for Question 316

# %% [markdown]
# ### **Question 317** *(Topic 13.17)*
# > Write a Python program to use the urllib module to make a simple HTTP GET request.

# %%
# TODO: Implement Solution for Question 317

# %% [markdown]
# ### **Question 318** *(Topic 13.18)*
# > How do you use the calendar module to print a month calendar and find weekdays?

# %%
# TODO: Implement Solution for Question 318

# %% [markdown]
# ### **Question 319** *(Topic 13.19)*
# > Write a Python program to use the statistics module to compute mean, median, mode, and stdev.

# %%
# TODO: Implement Solution for Question 319

# %% [markdown]
# ### **Question 320** *(Topic 13.20)*
# > How do you use the copy module to perform shallow and deep copies of objects?

# %%
# TODO: Implement Solution for Question 320

# %% [markdown]
# ### **Question 321** *(Topic 13.21)*
# > Write a Python program to use the string module constants (ascii_letters, digits, punctuation).

# %%
# TODO: Implement Solution for Question 321

# %% [markdown]
# ### **Question 322** *(Topic 13.22)*
# > How do you use the struct module to pack and unpack binary data?

# %%
# TODO: Implement Solution for Question 322

# %% [markdown]
# ### **Question 323** *(Topic 13.23)*
# > Write a Python program to use the textwrap module to wrap and dedent text.

# %%
# TODO: Implement Solution for Question 323

# %% [markdown]
# ### **Question 324** *(Topic 13.24)*
# > How do you use the pprint module to pretty-print nested data structures?

# %%
# TODO: Implement Solution for Question 324

# %% [markdown]
# ### **Question 325** *(Topic 13.25)*
# > Write a Python program to create a package with an __init__.py file and relative imports.

# %%
# TODO: Implement Solution for Question 325

# %% [markdown]
# ## Level 14: Topic 14: Regular Expressions
# ---

# %% [markdown]
# ### **Question 326** *(Topic 14.1)*
# > Write a Python program to check if a string matches a given regex pattern using re.match().

# %%
# TODO: Implement Solution for Question 326

# %% [markdown]
# ### **Question 327** *(Topic 14.2)*
# > How do you use re.search() to find the first occurrence of a pattern anywhere in a string?

# %%
# TODO: Implement Solution for Question 327

# %% [markdown]
# ### **Question 328** *(Topic 14.3)*
# > Write a Python program to find all occurrences of a pattern using re.findall().

# %%
# TODO: Implement Solution for Question 328

# %% [markdown]
# ### **Question 329** *(Topic 14.4)*
# > How do you use re.sub() to replace all occurrences of a pattern with a new string?

# %%
# TODO: Implement Solution for Question 329

# %% [markdown]
# ### **Question 330** *(Topic 14.5)*
# > Write a Python program to validate an email address using a regular expression.

# %%
# TODO: Implement Solution for Question 330

# %% [markdown]
# ### **Question 331** *(Topic 14.6)*
# > How do you validate a strong password (uppercase, lowercase, digit, special char, min 8 chars)?

# %%
# TODO: Implement Solution for Question 331

# %% [markdown]
# ### **Question 332** *(Topic 14.7)*
# > Write a Python program to extract all URLs from a block of text using regex.

# %%
# TODO: Implement Solution for Question 332

# %% [markdown]
# ### **Question 333** *(Topic 14.8)*
# > How do you use groups () in a regex to extract specific parts of a match (e.g., date components)?

# %%
# TODO: Implement Solution for Question 333

# %% [markdown]
# ### **Question 334** *(Topic 14.9)*
# > Write a Python program to split a string by multiple delimiters using re.split().

# %%
# TODO: Implement Solution for Question 334

# %% [markdown]
# ### **Question 335** *(Topic 14.10)*
# > How do you use named groups (?P<name>) in a regex pattern?

# %%
# TODO: Implement Solution for Question 335

# %% [markdown]
# ### **Question 336** *(Topic 14.11)*
# > Write a Python program to extract all numbers (integers and floats) from a string.

# %%
# TODO: Implement Solution for Question 336

# %% [markdown]
# ### **Question 337** *(Topic 14.12)*
# > How do you use re.compile() to precompile a pattern for repeated use?

# %%
# TODO: Implement Solution for Question 337

# %% [markdown]
# ### **Question 338** *(Topic 14.13)*
# > Write a Python program to check if a string contains only alphanumeric characters.

# %%
# TODO: Implement Solution for Question 338

# %% [markdown]
# ### **Question 339** *(Topic 14.14)*
# > How do you use lookahead (?=...) and lookbehind (?<=...) assertions?

# %%
# TODO: Implement Solution for Question 339

# %% [markdown]
# ### **Question 340** *(Topic 14.15)*
# > Write a Python program to remove all HTML tags from a string using regex.

# %%
# TODO: Implement Solution for Question 340

# %% [markdown]
# ### **Question 341** *(Topic 14.16)*
# > How do you use the re.IGNORECASE flag to perform case-insensitive matching?

# %%
# TODO: Implement Solution for Question 341

# %% [markdown]
# ### **Question 342** *(Topic 14.17)*
# > Write a Python program to validate an Indian mobile number (starts with 6–9, 10 digits).

# %%
# TODO: Implement Solution for Question 342

# %% [markdown]
# ### **Question 343** *(Topic 14.18)*
# > How do you use re.MULTILINE to match patterns at the start and end of each line?

# %%
# TODO: Implement Solution for Question 343

# %% [markdown]
# ### **Question 344** *(Topic 14.19)*
# > Write a Python program to find all words that start with a capital letter in a paragraph.

# %%
# TODO: Implement Solution for Question 344

# %% [markdown]
# ### **Question 345** *(Topic 14.20)*
# > How do you use the non-greedy quantifier *? vs * in pattern matching?

# %%
# TODO: Implement Solution for Question 345

# %% [markdown]
# ### **Question 346** *(Topic 14.21)*
# > Write a Python program to extract all hashtags from a social media post.

# %%
# TODO: Implement Solution for Question 346

# %% [markdown]
# ### **Question 347** *(Topic 14.22)*
# > How do you use re.fullmatch() to ensure the entire string matches a pattern?

# %%
# TODO: Implement Solution for Question 347

# %% [markdown]
# ### **Question 348** *(Topic 14.23)*
# > Write a Python program to find duplicate words in a sentence using a back-reference (\1).

# %%
# TODO: Implement Solution for Question 348

# %% [markdown]
# ### **Question 349** *(Topic 14.24)*
# > How do you use re.finditer() to get match objects with start/end positions?

# %%
# TODO: Implement Solution for Question 349

# %% [markdown]
# ### **Question 350** *(Topic 14.25)*
# > Write a Python program to tokenize a mathematical expression into numbers and operators using regex.

# %%
# TODO: Implement Solution for Question 350

# %% [markdown]
# ## Level 15: Topic 15: Iterators, Generators & Decorators
# ---

# %% [markdown]
# ### **Question 351** *(Topic 15.1)*
# > Write a Python program to implement a custom iterator class that generates squares of numbers.

# %%
# TODO: Implement Solution for Question 351

# %% [markdown]
# ### **Question 352** *(Topic 15.2)*
# > How do you use the __iter__ and __next__ methods to build an infinite counter?

# %%
# TODO: Implement Solution for Question 352

# %% [markdown]
# ### **Question 353** *(Topic 15.3)*
# > Write a Python generator function that yields prime numbers indefinitely.

# %%
# TODO: Implement Solution for Question 353

# %% [markdown]
# ### **Question 354** *(Topic 15.4)*
# > How do you use the next() function and StopIteration to control a custom iterator?

# %%
# TODO: Implement Solution for Question 354

# %% [markdown]
# ### **Question 355** *(Topic 15.5)*
# > Write a Python program to create a generator expression and compare it with a list comprehension.

# %%
# TODO: Implement Solution for Question 355

# %% [markdown]
# ### **Question 356** *(Topic 15.6)*
# > How do you use itertools.islice() to take a finite slice from an infinite generator?

# %%
# TODO: Implement Solution for Question 356

# %% [markdown]
# ### **Question 357** *(Topic 15.7)*
# > Write a Python program to implement a pipeline of generators to process a large data stream.

# %%
# TODO: Implement Solution for Question 357

# %% [markdown]
# ### **Question 358** *(Topic 15.8)*
# > How do you use yield from to delegate to a sub-generator?

# %%
# TODO: Implement Solution for Question 358

# %% [markdown]
# ### **Question 359** *(Topic 15.9)*
# > Write a Python program to implement a decorator that measures and prints function execution time.

# %%
# TODO: Implement Solution for Question 359

# %% [markdown]
# ### **Question 360** *(Topic 15.10)*
# > How do you use functools.wraps inside a decorator to preserve the original function's metadata?

# %%
# TODO: Implement Solution for Question 360

# %% [markdown]
# ### **Question 361** *(Topic 15.11)*
# > Write a Python program to implement a decorator that caches function results (memoization).

# %%
# TODO: Implement Solution for Question 361

# %% [markdown]
# ### **Question 362** *(Topic 15.12)*
# > How do you stack multiple decorators on a function?

# %%
# TODO: Implement Solution for Question 362

# %% [markdown]
# ### **Question 363** *(Topic 15.13)*
# > Write a Python program to implement a parameterized decorator (a decorator factory).

# %%
# TODO: Implement Solution for Question 363

# %% [markdown]
# ### **Question 364** *(Topic 15.14)*
# > How do you implement a class-based decorator?

# %%
# TODO: Implement Solution for Question 364

# %% [markdown]
# ### **Question 365** *(Topic 15.15)*
# > Write a Python program to create a generator that reads a large file line by line lazily.

# %%
# TODO: Implement Solution for Question 365

# %% [markdown]
# ### **Question 366** *(Topic 15.16)*
# > How do you implement a coroutine using yield that receives and processes sent values?

# %%
# TODO: Implement Solution for Question 366

# %% [markdown]
# ### **Question 367** *(Topic 15.17)*
# > Write a Python program to use itertools.count, cycle, and repeat.

# %%
# TODO: Implement Solution for Question 367

# %% [markdown]
# ### **Question 368** *(Topic 15.18)*
# > How do you use itertools.groupby() to group sorted data by a key?

# %%
# TODO: Implement Solution for Question 368

# %% [markdown]
# ### **Question 369** *(Topic 15.19)*
# > Write a Python program to implement a generator that produces Fibonacci numbers infinitely.

# %%
# TODO: Implement Solution for Question 369

# %% [markdown]
# ### **Question 370** *(Topic 15.20)*
# > How do you convert a generator to a list, tuple, or sum on the fly?

# %%
# TODO: Implement Solution for Question 370

# %% [markdown]
# ### **Question 371** *(Topic 15.21)*
# > Write a Python program to use a decorator to enforce argument type checking.

# %%
# TODO: Implement Solution for Question 371

# %% [markdown]
# ### **Question 372** *(Topic 15.22)*
# > How do you use contextlib.contextmanager to create a simple context manager using a generator?

# %%
# TODO: Implement Solution for Question 372

# %% [markdown]
# ### **Question 373** *(Topic 15.23)*
# > Write a Python program to chain multiple generators using itertools.chain().

# %%
# TODO: Implement Solution for Question 373

# %% [markdown]
# ### **Question 374** *(Topic 15.24)*
# > How do you implement a retry decorator that re-runs a function on exception up to n times?

# %%
# TODO: Implement Solution for Question 374

# %% [markdown]
# ### **Question 375** *(Topic 15.25)*
# > Write a Python program to implement a generator-based co-routine pipeline for data processing.

# %%
# TODO: Implement Solution for Question 375

# %% [markdown]
# ## Level 16: Topic 16: Comprehensions & Functional Programming
# ---

# %% [markdown]
# ### **Question 376** *(Topic 16.1)*
# > Write a Python program using a list comprehension to generate all Pythagorean triplets up to n.

# %%
# TODO: Implement Solution for Question 376

# %% [markdown]
# ### **Question 377** *(Topic 16.2)*
# > How do you use a dict comprehension to count character frequencies in a string?

# %%
# TODO: Implement Solution for Question 377

# %% [markdown]
# ### **Question 378** *(Topic 16.3)*
# > Write a Python program using a set comprehension to find unique vowels in a sentence.

# %%
# TODO: Implement Solution for Question 378

# %% [markdown]
# ### **Question 379** *(Topic 16.4)*
# > How do you use a nested list comprehension to multiply two matrices?

# %%
# TODO: Implement Solution for Question 379

# %% [markdown]
# ### **Question 380** *(Topic 16.5)*
# > Write a Python program to use map() with a lambda to convert Celsius temperatures to Fahrenheit.

# %%
# TODO: Implement Solution for Question 380

# %% [markdown]
# ### **Question 381** *(Topic 16.6)*
# > How do you use filter() with a lambda to select words longer than 5 characters from a list?

# %%
# TODO: Implement Solution for Question 381

# %% [markdown]
# ### **Question 382** *(Topic 16.7)*
# > Write a Python program to use reduce() to compute the product of all elements in a list.

# %%
# TODO: Implement Solution for Question 382

# %% [markdown]
# ### **Question 383** *(Topic 16.8)*
# > How do you compose functions using functools.reduce() to build a processing pipeline?

# %%
# TODO: Implement Solution for Question 383

# %% [markdown]
# ### **Question 384** *(Topic 16.9)*
# > Write a Python program to use zip() and map() together to add two lists element-wise.

# %%
# TODO: Implement Solution for Question 384

# %% [markdown]
# ### **Question 385** *(Topic 16.10)*
# > How do you implement a flatten function using recursion vs. list comprehension?

# %%
# TODO: Implement Solution for Question 385

# %% [markdown]
# ### **Question 386** *(Topic 16.11)*
# > Write a Python program to use sorted() with a key function to sort complex objects.

# %%
# TODO: Implement Solution for Question 386

# %% [markdown]
# ### **Question 387** *(Topic 16.12)*
# > How do you implement a group_by function using defaultdict and a key function?

# %%
# TODO: Implement Solution for Question 387

# %% [markdown]
# ### **Question 388** *(Topic 16.13)*
# > Write a Python program to use operator.itemgetter as a key for sorting a list of tuples.

# %%
# TODO: Implement Solution for Question 388

# %% [markdown]
# ### **Question 389** *(Topic 16.14)*
# > How do you use functools.partial to create specialized versions of a generic function?

# %%
# TODO: Implement Solution for Question 389

# %% [markdown]
# ### **Question 390** *(Topic 16.15)*
# > Write a Python program to implement function currying manually (returning nested lambdas).

# %%
# TODO: Implement Solution for Question 390

# %% [markdown]
# ### **Question 391** *(Topic 16.16)*
# > How do you use any() and all() with generator expressions for validation checks?

# %%
# TODO: Implement Solution for Question 391

# %% [markdown]
# ### **Question 392** *(Topic 16.17)*
# > Write a Python program to implement a memoization decorator using a dictionary cache.

# %%
# TODO: Implement Solution for Question 392

# %% [markdown]
# ### **Question 393** *(Topic 16.18)*
# > How do you chain filter(), map(), and sorted() into a single readable expression?

# %%
# TODO: Implement Solution for Question 393

# %% [markdown]
# ### **Question 394** *(Topic 16.19)*
# > Write a Python program to use itertools.starmap() to apply a function to tuples in a list.

# %%
# TODO: Implement Solution for Question 394

# %% [markdown]
# ### **Question 395** *(Topic 16.20)*
# > How do you implement a pipeline function that applies a sequence of transforms to data?

# %%
# TODO: Implement Solution for Question 395

# %% [markdown]
# ### **Question 396** *(Topic 16.21)*
# > Write a Python program to use a list comprehension with multiple if conditions.

# %%
# TODO: Implement Solution for Question 396

# %% [markdown]
# ### **Question 397** *(Topic 16.22)*
# > How do you use dict comprehension with zip() to pair two lists into a dictionary?

# %%
# TODO: Implement Solution for Question 397

# %% [markdown]
# ### **Question 398** *(Topic 16.23)*
# > Write a Python program to use a generator expression inside sum() to compute weighted averages.

# %%
# TODO: Implement Solution for Question 398

# %% [markdown]
# ### **Question 399** *(Topic 16.24)*
# > How do you use the walrus operator (:=) inside a comprehension for efficiency?

# %%
# TODO: Implement Solution for Question 399

# %% [markdown]
# ### **Question 400** *(Topic 16.25)*
# > Write a Python program to implement a declarative data transformation pipeline without explicit loops.

# %%
# TODO: Implement Solution for Question 400

# %% [markdown]
# ## Level 17: Topic 17: Data Structures — Stacks, Queues, Linked Lists & Trees
# ---

# %% [markdown]
# ### **Question 401** *(Topic 17.1)*
# > Write a Python program to implement a stack using a list with push, pop, peek, and is_empty operations.

# %%
# TODO: Implement Solution for Question 401

# %% [markdown]
# ### **Question 402** *(Topic 17.2)*
# > How do you use collections.deque to implement a stack and a queue efficiently?

# %%
# TODO: Implement Solution for Question 402

# %% [markdown]
# ### **Question 403** *(Topic 17.3)*
# > Write a Python program to implement a queue using two stacks.

# %%
# TODO: Implement Solution for Question 403

# %% [markdown]
# ### **Question 404** *(Topic 17.4)*
# > How do you implement a circular queue using a fixed-size list?

# %%
# TODO: Implement Solution for Question 404

# %% [markdown]
# ### **Question 405** *(Topic 17.5)*
# > Write a Python program to implement a singly linked list with insert, delete, and display operations.

# %%
# TODO: Implement Solution for Question 405

# %% [markdown]
# ### **Question 406** *(Topic 17.6)*
# > How do you detect a cycle in a linked list using Floyd's two-pointer algorithm?

# %%
# TODO: Implement Solution for Question 406

# %% [markdown]
# ### **Question 407** *(Topic 17.7)*
# > Write a Python program to reverse a singly linked list iteratively and recursively.

# %%
# TODO: Implement Solution for Question 407

# %% [markdown]
# ### **Question 408** *(Topic 17.8)*
# > How do you implement a doubly linked list with forward and backward traversal?

# %%
# TODO: Implement Solution for Question 408

# %% [markdown]
# ### **Question 409** *(Topic 17.9)*
# > Write a Python program to implement a binary search tree (BST) with insert, search, and inorder traversal.

# %%
# TODO: Implement Solution for Question 409

# %% [markdown]
# ### **Question 410** *(Topic 17.10)*
# > How do you find the height (depth) of a binary tree using recursion?

# %%
# TODO: Implement Solution for Question 410

# %% [markdown]
# ### **Question 411** *(Topic 17.11)*
# > Write a Python program to implement level-order (BFS) traversal of a binary tree.

# %%
# TODO: Implement Solution for Question 411

# %% [markdown]
# ### **Question 412** *(Topic 17.12)*
# > How do you implement preorder, inorder, and postorder tree traversal?

# %%
# TODO: Implement Solution for Question 412

# %% [markdown]
# ### **Question 413** *(Topic 17.13)*
# > Write a Python program to check if a binary tree is balanced.

# %%
# TODO: Implement Solution for Question 413

# %% [markdown]
# ### **Question 414** *(Topic 17.14)*
# > How do you find the lowest common ancestor (LCA) of two nodes in a BST?

# %%
# TODO: Implement Solution for Question 414

# %% [markdown]
# ### **Question 415** *(Topic 17.15)*
# > Write a Python program to implement a min-heap and max-heap using the heapq module.

# %%
# TODO: Implement Solution for Question 415

# %% [markdown]
# ### **Question 416** *(Topic 17.16)*
# > How do you use heapq.nlargest() and nsmallest() to find top-k elements from a list?

# %%
# TODO: Implement Solution for Question 416

# %% [markdown]
# ### **Question 417** *(Topic 17.17)*
# > Write a Python program to implement a graph as an adjacency list and adjacency matrix.

# %%
# TODO: Implement Solution for Question 417

# %% [markdown]
# ### **Question 418** *(Topic 17.18)*
# > How do you implement Depth-First Search (DFS) on a graph using a stack and recursion?

# %%
# TODO: Implement Solution for Question 418

# %% [markdown]
# ### **Question 419** *(Topic 17.19)*
# > Write a Python program to implement Breadth-First Search (BFS) on a graph using a queue.

# %%
# TODO: Implement Solution for Question 419

# %% [markdown]
# ### **Question 420** *(Topic 17.20)*
# > How do you detect a cycle in a directed graph using DFS and coloring?

# %%
# TODO: Implement Solution for Question 420

# %% [markdown]
# ### **Question 421** *(Topic 17.21)*
# > Write a Python program to implement a priority queue using heapq.

# %%
# TODO: Implement Solution for Question 421

# %% [markdown]
# ### **Question 422** *(Topic 17.22)*
# > How do you implement a trie (prefix tree) for efficient word search and autocomplete?

# %%
# TODO: Implement Solution for Question 422

# %% [markdown]
# ### **Question 423** *(Topic 17.23)*
# > Write a Python program to find the shortest path in an unweighted graph using BFS.

# %%
# TODO: Implement Solution for Question 423

# %% [markdown]
# ### **Question 424** *(Topic 17.24)*
# > How do you implement Dijkstra's algorithm for shortest path in a weighted graph?

# %%
# TODO: Implement Solution for Question 424

# %% [markdown]
# ### **Question 425** *(Topic 17.25)*
# > Write a Python program to implement a hash table from scratch with collision handling using chaining.

# %%
# TODO: Implement Solution for Question 425

# %% [markdown]
# ## Level 18: Topic 18: Algorithms — Searching, Sorting & Recursion
# ---

# %% [markdown]
# ### **Question 426** *(Topic 18.1)*
# > Write a Python program to implement linear search and binary search on a list.

# %%
# TODO: Implement Solution for Question 426

# %% [markdown]
# ### **Question 427** *(Topic 18.2)*
# > How do you implement binary search recursively and iteratively?

# %%
# TODO: Implement Solution for Question 427

# %% [markdown]
# ### **Question 428** *(Topic 18.3)*
# > Write a Python program to implement bubble sort and analyze its time complexity.

# %%
# TODO: Implement Solution for Question 428

# %% [markdown]
# ### **Question 429** *(Topic 18.4)*
# > How do you implement selection sort and insertion sort?

# %%
# TODO: Implement Solution for Question 429

# %% [markdown]
# ### **Question 430** *(Topic 18.5)*
# > Write a Python program to implement merge sort using divide and conquer.

# %%
# TODO: Implement Solution for Question 430

# %% [markdown]
# ### **Question 431** *(Topic 18.6)*
# > How do you implement quicksort with a pivot selection strategy?

# %%
# TODO: Implement Solution for Question 431

# %% [markdown]
# ### **Question 432** *(Topic 18.7)*
# > Write a Python program to implement heap sort using the heapq module.

# %%
# TODO: Implement Solution for Question 432

# %% [markdown]
# ### **Question 433** *(Topic 18.8)*
# > How do you implement counting sort for non-negative integers?

# %%
# TODO: Implement Solution for Question 433

# %% [markdown]
# ### **Question 434** *(Topic 18.9)*
# > Write a Python program to implement radix sort.

# %%
# TODO: Implement Solution for Question 434

# %% [markdown]
# ### **Question 435** *(Topic 18.10)*
# > How do you solve the Tower of Hanoi problem using recursion?

# %%
# TODO: Implement Solution for Question 435

# %% [markdown]
# ### **Question 436** *(Topic 18.11)*
# > Write a Python program to find all permutations of a string using recursion.

# %%
# TODO: Implement Solution for Question 436

# %% [markdown]
# ### **Question 437** *(Topic 18.12)*
# > How do you implement the Knapsack problem (0/1) using dynamic programming?

# %%
# TODO: Implement Solution for Question 437

# %% [markdown]
# ### **Question 438** *(Topic 18.13)*
# > Write a Python program to solve the Fibonacci problem using DP (top-down and bottom-up).

# %%
# TODO: Implement Solution for Question 438

# %% [markdown]
# ### **Question 439** *(Topic 18.14)*
# > How do you implement the longest common subsequence (LCS) algorithm?

# %%
# TODO: Implement Solution for Question 439

# %% [markdown]
# ### **Question 440** *(Topic 18.15)*
# > Write a Python program to implement the coin change problem using dynamic programming.

# %%
# TODO: Implement Solution for Question 440

# %% [markdown]
# ### **Question 441** *(Topic 18.16)*
# > How do you implement binary exponentiation to compute a^b mod m efficiently?

# %%
# TODO: Implement Solution for Question 441

# %% [markdown]
# ### **Question 442** *(Topic 18.17)*
# > Write a Python program to implement the Sieve of Eratosthenes to find all primes up to n.

# %%
# TODO: Implement Solution for Question 442

# %% [markdown]
# ### **Question 443** *(Topic 18.18)*
# > How do you implement a two-pointer technique to find pairs summing to a target in a sorted list?

# %%
# TODO: Implement Solution for Question 443

# %% [markdown]
# ### **Question 444** *(Topic 18.19)*
# > Write a Python program to implement the sliding window technique to find the maximum sum subarray of size k.

# %%
# TODO: Implement Solution for Question 444

# %% [markdown]
# ### **Question 445** *(Topic 18.20)*
# > How do you implement depth-first backtracking to solve the N-Queens problem?

# %%
# TODO: Implement Solution for Question 445

# %% [markdown]
# ### **Question 446** *(Topic 18.21)*
# > Write a Python program to find the maximum subarray sum using Kadane's algorithm.

# %%
# TODO: Implement Solution for Question 446

# %% [markdown]
# ### **Question 447** *(Topic 18.22)*
# > How do you implement topological sort of a directed acyclic graph (DAG)?

# %%
# TODO: Implement Solution for Question 447

# %% [markdown]
# ### **Question 448** *(Topic 18.23)*
# > Write a Python program to implement the matrix chain multiplication problem using DP.

# %%
# TODO: Implement Solution for Question 448

# %% [markdown]
# ### **Question 449** *(Topic 18.24)*
# > How do you implement a greedy algorithm for the activity selection problem?

# %%
# TODO: Implement Solution for Question 449

# %% [markdown]
# ### **Question 450** *(Topic 18.25)*
# > Write a Python program to implement the edit distance (Levenshtein distance) between two strings.

# %%
# TODO: Implement Solution for Question 450

# %% [markdown]
# ## Level 19: Topic 19: Concurrency — Multithreading, Multiprocessing & Async
# ---

# %% [markdown]
# ### **Question 451** *(Topic 19.1)*
# > Write a Python program to create and start multiple threads using the threading module.

# %%
# TODO: Implement Solution for Question 451

# %% [markdown]
# ### **Question 452** *(Topic 19.2)*
# > How do you use threading.Lock() to prevent race conditions in a shared counter?

# %%
# TODO: Implement Solution for Question 452

# %% [markdown]
# ### **Question 453** *(Topic 19.3)*
# > Write a Python program to implement a producer-consumer pattern using threading and queue.Queue.

# %%
# TODO: Implement Solution for Question 453

# %% [markdown]
# ### **Question 454** *(Topic 19.4)*
# > How do you use threading.Event to signal between threads?

# %%
# TODO: Implement Solution for Question 454

# %% [markdown]
# ### **Question 455** *(Topic 19.5)*
# > Write a Python program to use threading.Semaphore to limit concurrent access to a resource.

# %%
# TODO: Implement Solution for Question 455

# %% [markdown]
# ### **Question 456** *(Topic 19.6)*
# > How do you use a ThreadPoolExecutor from concurrent.futures to parallelize tasks?

# %%
# TODO: Implement Solution for Question 456

# %% [markdown]
# ### **Question 457** *(Topic 19.7)*
# > Write a Python program to use multiprocessing.Process to spawn child processes.

# %%
# TODO: Implement Solution for Question 457

# %% [markdown]
# ### **Question 458** *(Topic 19.8)*
# > How do you use multiprocessing.Pool.map() to parallelize a CPU-bound task?

# %%
# TODO: Implement Solution for Question 458

# %% [markdown]
# ### **Question 459** *(Topic 19.9)*
# > Write a Python program to share data between processes using multiprocessing.Queue and Pipe.

# %%
# TODO: Implement Solution for Question 459

# %% [markdown]
# ### **Question 460** *(Topic 19.10)*
# > How do you use multiprocessing.Value and Array for shared memory between processes?

# %%
# TODO: Implement Solution for Question 460

# %% [markdown]
# ### **Question 461** *(Topic 19.11)*
# > Write a Python program to use ProcessPoolExecutor for parallel computation.

# %%
# TODO: Implement Solution for Question 461

# %% [markdown]
# ### **Question 462** *(Topic 19.12)*
# > How do you implement an async function using async def and await with asyncio?

# %%
# TODO: Implement Solution for Question 462

# %% [markdown]
# ### **Question 463** *(Topic 19.13)*
# > Write a Python program to run multiple coroutines concurrently using asyncio.gather().

# %%
# TODO: Implement Solution for Question 463

# %% [markdown]
# ### **Question 464** *(Topic 19.14)*
# > How do you use asyncio.create_task() to schedule independent coroutines?

# %%
# TODO: Implement Solution for Question 464

# %% [markdown]
# ### **Question 465** *(Topic 19.15)*
# > Write a Python program to implement an async producer-consumer pattern with asyncio.Queue.

# %%
# TODO: Implement Solution for Question 465

# %% [markdown]
# ### **Question 466** *(Topic 19.16)*
# > How do you use asyncio.sleep() as a non-blocking delay inside a coroutine?

# %%
# TODO: Implement Solution for Question 466

# %% [markdown]
# ### **Question 467** *(Topic 19.17)*
# > Write a Python program to fetch multiple URLs concurrently using aiohttp and asyncio.

# %%
# TODO: Implement Solution for Question 467

# %% [markdown]
# ### **Question 468** *(Topic 19.18)*
# > How do you handle timeouts in async operations using asyncio.wait_for()?

# %%
# TODO: Implement Solution for Question 468

# %% [markdown]
# ### **Question 469** *(Topic 19.19)*
# > Write a Python program to implement a simple async TCP server using asyncio streams.

# %%
# TODO: Implement Solution for Question 469

# %% [markdown]
# ### **Question 470** *(Topic 19.20)*
# > How do you use asyncio.Lock() to synchronize access in coroutines?

# %%
# TODO: Implement Solution for Question 470

# %% [markdown]
# ### **Question 471** *(Topic 19.21)*
# > Write a Python program to compare the performance of sequential vs. threaded vs. async approaches.

# %%
# TODO: Implement Solution for Question 471

# %% [markdown]
# ### **Question 472** *(Topic 19.22)*
# > How do you avoid deadlocks in a multithreaded program using lock ordering?

# %%
# TODO: Implement Solution for Question 472

# %% [markdown]
# ### **Question 473** *(Topic 19.23)*
# > Write a Python program to use concurrent.futures.as_completed() to handle results as they arrive.

# %%
# TODO: Implement Solution for Question 473

# %% [markdown]
# ### **Question 474** *(Topic 19.24)*
# > How do you profile and debug multithreaded programs using threading.enumerate()?

# %%
# TODO: Implement Solution for Question 474

# %% [markdown]
# ### **Question 475** *(Topic 19.25)*
# > Write a Python program to implement a rate-limiter using asyncio to throttle concurrent requests.

# %%
# TODO: Implement Solution for Question 475

# %% [markdown]
# ## Level 20: Topic 20: Advanced Python — Metaclasses, Memory, Testing & Best Practices
# ---

# %% [markdown]
# ### **Question 476** *(Topic 20.1)*
# > Write a Python program to implement a metaclass that enforces all method names to be lowercase.

# %%
# TODO: Implement Solution for Question 476

# %% [markdown]
# ### **Question 477** *(Topic 20.2)*
# > How do you use type() to dynamically create a class at runtime?

# %%
# TODO: Implement Solution for Question 477

# %% [markdown]
# ### **Question 478** *(Topic 20.3)*
# > Write a Python program to implement __init_subclass__ to automatically register subclasses.

# %%
# TODO: Implement Solution for Question 478

# %% [markdown]
# ### **Question 479** *(Topic 20.4)*
# > How do you use __new__ to control instance creation in a Singleton pattern?

# %%
# TODO: Implement Solution for Question 479

# %% [markdown]
# ### **Question 480** *(Topic 20.5)*
# > Write a Python program to use the gc module to inspect and manually trigger garbage collection.

# %%
# TODO: Implement Solution for Question 480

# %% [markdown]
# ### **Question 481** *(Topic 20.6)*
# > How do you use weakref to create weak references and avoid memory leaks?

# %%
# TODO: Implement Solution for Question 481

# %% [markdown]
# ### **Question 482** *(Topic 20.7)*
# > Write a Python program to profile memory usage using tracemalloc.

# %%
# TODO: Implement Solution for Question 482

# %% [markdown]
# ### **Question 483** *(Topic 20.8)*
# > How do you use the cProfile module to identify performance bottlenecks in a program?

# %%
# TODO: Implement Solution for Question 483

# %% [markdown]
# ### **Question 484** *(Topic 20.9)*
# > Write a Python program to use line_profiler or timeit to benchmark specific lines of code.

# %%
# TODO: Implement Solution for Question 484

# %% [markdown]
# ### **Question 485** *(Topic 20.10)*
# > How do you write unit tests for a function using the unittest module?

# %%
# TODO: Implement Solution for Question 485

# %% [markdown]
# ### **Question 486** *(Topic 20.11)*
# > Write a Python program to use unittest.mock.patch to mock an external API call in a test.

# %%
# TODO: Implement Solution for Question 486

# %% [markdown]
# ### **Question 487** *(Topic 20.12)*
# > How do you use pytest fixtures to set up and tear down test environments?

# %%
# TODO: Implement Solution for Question 487

# %% [markdown]
# ### **Question 488** *(Topic 20.13)*
# > Write a Python program to test exception raising using unittest.assertRaises().

# %%
# TODO: Implement Solution for Question 488

# %% [markdown]
# ### **Question 489** *(Topic 20.14)*
# > How do you use property-based testing with the hypothesis library?

# %%
# TODO: Implement Solution for Question 489

# %% [markdown]
# ### **Question 490** *(Topic 20.15)*
# > Write a Python program to implement a context manager using __enter__ and __exit__ for DB simulation.

# %%
# TODO: Implement Solution for Question 490

# %% [markdown]
# ### **Question 491** *(Topic 20.16)*
# > How do you use __getattr__, __setattr__, and __delattr__ to intercept attribute access?

# %%
# TODO: Implement Solution for Question 491

# %% [markdown]
# ### **Question 492** *(Topic 20.17)*
# > Write a Python program to implement a descriptor class with __get__, __set__, and __delete__.

# %%
# TODO: Implement Solution for Question 492

# %% [markdown]
# ### **Question 493** *(Topic 20.18)*
# > How do you use __class_getitem__ to support generic class syntax (e.g., MyClass[int])?

# %%
# TODO: Implement Solution for Question 493

# %% [markdown]
# ### **Question 494** *(Topic 20.19)*
# > Write a Python program to enforce immutability by overriding __setattr__ to raise AttributeError.

# %%
# TODO: Implement Solution for Question 494

# %% [markdown]
# ### **Question 495** *(Topic 20.20)*
# > How do you use sys.intern to optimize memory for repeated string values?

# %%
# TODO: Implement Solution for Question 495

# %% [markdown]
# ### **Question 496** *(Topic 20.21)*
# > Write a Python program to demonstrate the difference between deep copy and shallow copy with nested objects.

# %%
# TODO: Implement Solution for Question 496

# %% [markdown]
# ### **Question 497** *(Topic 20.22)*
# > How do you use __slots__ in a class to reduce per-instance memory overhead?

# %%
# TODO: Implement Solution for Question 497

# %% [markdown]
# ### **Question 498** *(Topic 20.23)*
# > Write a Python program to implement a publish-subscribe event system using dictionaries of callbacks.

# %%
# TODO: Implement Solution for Question 498

# %% [markdown]
# ### **Question 499** *(Topic 20.24)*
# > How do you use abstract base classes (ABC) to enforce interface contracts across subclasses?

# %%
# TODO: Implement Solution for Question 499

# %% [markdown]
# ### **Question 500** *(Topic 20.25)*
# > Write a Python program that combines metaclasses, descriptors, decorators, and generators to build a mini ORM (Object-Relational Mapper) framework.

# %%
# TODO: Implement Solution for Question 500
